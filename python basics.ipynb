# %%
print("Hello world")
# Out:
# Hello world

# %%
print(5*6)
# Out:
# 30

# %%
#this is comment

# %%
l=[1,2,3,4]
l
# Out:
# [1, 2, 3, 4]

# %%
s=["windows","linux","mac"]
s
# Out:
# ['windows', 'linux', 'mac']

# %%
x=[1,"hi",4.03]
x
# Out:
# [1, 'hi', 4.03]

# %%
t=("hi","hello","how are you")
t
# Out:
# ('hi', 'hello', 'how are you')

# %%
t=("hi",4.0)
t
# Out:
# ('hi', 4.0)

# %%
a=4
if a%2==0:
    print(1)
else:
    print(0)
# Out:
# 1

# %%
i=1
while i<5:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4

# %%
vegetables=["potato","cabbage","onion"]
for x in vegetables:
    print(x)
# Out:
# potato
# cabbage
# onion

# %%
def myfunction(a):
    if a % 2 == 0:
        return 1
    else:
        return 0

result = myfunction(5)
print(result)
# Out:
# 0

# %%
x=lambda a:a+1
print(x(5))
# Out:
# 6
